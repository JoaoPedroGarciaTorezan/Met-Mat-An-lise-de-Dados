# %% [markdown]
# ## Teste de Duas Proporções

# %% [markdown]
# Em uma amostra de 200 itens de um fornecedor A foram encontrados 30 itens defeituosos. Em outra amostra de 100 itens de um fornecedor B foram encontrados 10 defeituosos. Há uma diferença significativa na qualidade dos produtos desses fornecedores? Nível de confiança: 95%.

# %% [markdown]
# H0: p1 - p2 = 0 \
# Ha: p1 - p2 ≠ 0

# %%
from statsmodels.stats import proportion

# %%
proportion.test_proportions_2indep(30, 200, 10, 100, method='score') # zcal = statistics
# Out:
# <class 'statsmodels.stats.base.HolderTuple'>
# statistic = np.float64(1.1989578808281796)
# pvalue = np.float64(0.2305443235633593)
# compare = 'diff'
# method = 'score'
# variance = np.float64(0.001739130434782609)
# alternative = 'two-sided'
# prop1_null = np.float64(0.13333333333333333)
# prop2_null = np.float64(0.13333333333333333)
# tuple = (np.float64(1.1989578808281796), np.float64(0.2305443235633593))
# diff = np.float64(0.04999999999999999)
# ratio = np.float64(1.4999999999999998)
# odds_ratio = np.float64(1.588235294117647)
# value = 0

# %% [markdown]
# Resposta: tendo em vista que pValue = 0.23 > 0.05, falhamos em rejeitar a hipotese nula. Portanto não a diferença significativa de qualidade entre os fornecedores A e B.

# %% [markdown]
# Exercício \
# Em um estudo de 200 mulheres adultas selecionadas aleatoriamente e 250 homens adultos, ambos usuários de Internet, 30% das mulheres e 38% dos homens disseram que planejam comprar online ao menos uma vez no mês seguinte. Ao nível de confiança de 90%, testar a afirmação de que há uma diferença entre a proporção de homens e mulheres, usuários de Internet, que planejam comprar online. \
# A) Calcular manualmente \
# B) Calcular utilizando o Python

# %% [markdown]
# H0: p1 - p2 = 0 \
# Ha: p1 - p2 ≠ 0

# %%
homens = 0.38*250
mulheres = 0.3*200

proportion.test_proportions_2indep(homens, 250, mulheres, 200, method = 'score')
# Out:
# <class 'statsmodels.stats.base.HolderTuple'>
# statistic = np.float64(1.772643092104187)
# pvalue = np.float64(0.0762878664367035)
# compare = 'diff'
# method = 'score'
# variance = np.float64(0.0020367483296213807)
# alternative = 'two-sided'
# prop1_null = np.float64(0.34444444444444444)
# prop2_null = np.float64(0.34444444444444444)
# tuple = (np.float64(1.772643092104187), np.float64(0.0762878664367035))
# diff = np.float64(0.08000000000000002)
# ratio = np.float64(1.2666666666666668)
# odds_ratio = np.float64(1.4301075268817203)
# value = 0

# %% [markdown]
# Resposta: Já que pvalue < 0.1, rejeitamos a hipótese nula. Logo, a uma diferença na proporção de homens e mulheres.
