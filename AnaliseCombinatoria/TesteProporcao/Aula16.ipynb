# %% [markdown]
# ## Teste de uma proporção

# %% [markdown]
# Taxa de fumantes em uma cidade era 21%. Uma amostra de 100 habitantes encontrou 14 fumantes. A proporção de fumantes da cidade mudou (nível de confiança = 95%)?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# H0: p = p0 \
# HA: p ≠ p0

# %%
stats.binomtest(14, 100, p=0.21, alternative='two-sided')
# Out:
# BinomTestResult(k=14, n=100, alternative='two-sided', statistic=0.14, pvalue=0.10920815720825927)

# %% [markdown]
# Conclusão: Como tivemos pValue > 0.05 (alpha), falhamos em rejeitar a hip nula. Portanto, a proporção de fumantes NÃO mudou

# %% [markdown]
# Taxa de fumantes em uma cidade era 21%. Uma amostra de 100 habitantes encontrou 14 fumantes. A proporção de fumantes da cidade reduziu? (uma cauda – nível de confiança = 95%).

# %% [markdown]
# H0: p >= p0 \
# HA: p < p0

# %%
stats.binomtest(14, 100, p=0.21, alternative='less') #less -> cauda da esquerda; greater -> cauda da direita
# Out:
# BinomTestResult(k=14, n=100, alternative='less', statistic=0.14, pvalue=0.05042460221552124)

# %% [markdown]
# Se pValue > 0.05 -> falha em rej. H0
# Se pValue < 0.05 -> rejeita H0

# %% [markdown]
# Conclusão: Como tivemos pValue > 0.05, falhamos em rejeitar a hipótese nula. Portanto, a proporção de fumantes NÃO reduziu.

# %% [markdown]
# Exercício 1 \
# Uma empresa realizou uma campanha anti-tabagismo visando diminuir a proporção de seus trabalhadores que são fumantes. Sabe-se que antes da campanha 21% dos trabalhadores se declaravam fumantes. Para verificar se essa porcentagem mudou após a campanha, a empresa coletou informações de 100 funcionários e armazenou o resultado no arquivo Smokers.csv. Realize um teste de hipótese e informe se a proporção de fumantes continua a mesma ou mudou.

# %%
df = pd.read_csv('Smokers.csv')
df.head()
# Out:
#        Name Smokers
# 0  Person 1      No
# 1  Person 2      No
# 2  Person 3      No
# 3  Person 4     Yes
# 4  Person 5      No

# %%
fumantes = df.groupby('Smokers').count()
fumantes
# Out:
#          Name
# Smokers
# No         83
# Yes        17

# %%
nro_fumantes = fumantes.loc['Yes'].values[0]
nro_fumantes
# Out:
# np.int64(17)

# %% [markdown]
# H0: p = p0
# HA: p != p0

# %%
stats.binomtest(nro_fumantes, 100, p=0.21, alternative='two-sided')
# Out:
# BinomTestResult(k=17, n=100, alternative='two-sided', statistic=0.17, pvalue=0.39008168921916636)

# %% [markdown]
# Conclusão: Como pValue > 0.05, falhamos em rejeitar a hipótese nula. Portanto, a proporção de fumantes NÃO mudou.

# %% [markdown]
# Exercício 2 \
# Uma estimativa feita por um instituto de pesquisa apontou que 25% das mulheres que frequentam restaurantes numa dada cidade são fumantes. O dono de um restaurante decidiu testar uma amostra de suas clientes para verificar se esta estimativa é correta. Realize o teste de uma proporção com os dados contidos em 'tips.csv' e informe se a estimativa está correta (nível de confiança = 95%).

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# H0: p = p0
# HA: p != p0

# %%
mulheres = df[df['sex'] == 'Female']
nro_mulheres = mulheres[mulheres['smoker'] == 'Yes'].count()
nro_mulheres = nro_mulheres['smoker']
nro_mulheres
# Out:
# np.int64(33)

# %%
stats.binomtest(nro_mulheres, 87, p=0.25, alternative='two-sided')
# Out:
# BinomTestResult(k=33, n=87, alternative='two-sided', statistic=0.3793103448275862, pvalue=0.008747732318429489)

# %% [markdown]
# Conclusão: Como pValue < 0.05, rejeitamos a hipótese nula. Portanto, a proporção de fumantes mudou. (diferente de 25%)

# %% [markdown]
# Exercício 3 \
# Uma empresa afirma que 70% dos seus clientes estão satisfeitos. Pesquisamos 100 clientes e descobrimos que 65 estão satisfeitos. Queremos testar se a verdadeira proporção de clientes satisfeitos é significativamente diferente de 70%. Confiança: 95%.
#
# Apresente a solução: \
# a) Em python; \
# b) Utilizando a curva normal.

# %% [markdown]
# H0: p = po
# HA: p != p0

# %%
stats.binomtest(65, 100, p=0.70, alternative='two-sided')
# Out:
# BinomTestResult(k=65, n=100, alternative='two-sided', statistic=0.65, pvalue=0.27642847007596916)

# %% [markdown]
# Conclusão:
