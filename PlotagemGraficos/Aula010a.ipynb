# %% [markdown]
# ## Gráfico de Linhas
# Vamos criar um gráfico de linhas para analisar a evolução do preço das ações das empresas Tesla e Apple.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tesla.csv')

# %%
df.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2020-01-02 00:00:00-05:00  28.299999  28.713333  28.114000  28.684000
# 1  2020-01-03 00:00:00-05:00  29.366667  30.266666  29.128000  29.534000
# 2  2020-01-06 00:00:00-05:00  29.364668  30.104000  29.333332  30.102667
# 3  2020-01-07 00:00:00-05:00  30.760000  31.441999  30.224001  31.270666
# 4  2020-01-08 00:00:00-05:00  31.580000  33.232666  31.215334  32.809334
#
#       Volume  Dividends  Stock Splits
# 0  142981500        0.0           0.0
# 1  266677500        0.0           0.0
# 2  151995000        0.0           0.0
# 3  268231500        0.0           0.0
# 4  467164500        0.0           0.0

# %%
df2 = pd.read_csv('apple.csv', index_col='Date', parse_dates=True)

# %%
df['Close AAPL'] = df2['Close']
df.rename(columns={'Close': 'Close TSLA'}, inplace=True)
df.head()
# Out:
#                         Date       Open       High        Low  Close TSLA  \
# 0  2020-01-02 00:00:00-05:00  28.299999  28.713333  28.114000   28.684000
# 1  2020-01-03 00:00:00-05:00  29.366667  30.266666  29.128000   29.534000
# 2  2020-01-06 00:00:00-05:00  29.364668  30.104000  29.333332   30.102667
# 3  2020-01-07 00:00:00-05:00  30.760000  31.441999  30.224001   31.270666
# 4  2020-01-08 00:00:00-05:00  31.580000  33.232666  31.215334   32.809334
#
#       Volume  Dividends  Stock Splits  Close AAPL
# 0  142981500        0.0           0.0         NaN
# 1  266677500        0.0           0.0         NaN
# 2  151995000        0.0           0.0         NaN
# 3  268231500        0.0           0.0         NaN
# 4  467164500        0.0           0.0         NaN

# %%
plt.rcParams['figure.figsize'] = [12,8]
sns.set_style('darkgrid')
df[['Close TSLA', 'Close AAPL']].plot()
plt.title('Preço da ações da tesla e da apple')
plt.xlabel('tempo')
plt.ylabel('Preço')
plt.show()

# %% [markdown]
# Vamos agora utilizar o dataset LifeExpectancy para criar um gráfico de barras.

# %%
df3 = pd.read_csv('lifeExpectancy.csv')
df3.head(15)
# Out:
#                    Countries  Males  Females
# 0                    Algeria     69       73
# 1                     Angola     50       53
# 2                      Benin     58       61
# 3               Burkina Faso     55       56
# 4                    Burundi     52       56
# 5                 Cabo Verde     71       79
# 6                   Cameroon     54       56
# 7   Central African Republic     48       51
# 8                       Chad     50       52
# 9           Congo, Dem. Rep.     48       51
# 10               Congo, Rep.     57       60
# 11             Cote d'Ivoire     50       51
# 12                  Djibouti     60       63
# 13          Egypt, Arab Rep.     69       73
# 14         Equatorial Guinea     51       54

# %% [markdown]
# Nosso gráfico deve permitir comparar a expectativa de vida de homens e mulheres de países africanos.

# %%
df3.plot(x='Countries', kind='bar', stacked=False)
plt.title('Comparando as expectativa de vida em paíese africandos')
plt.xlabel('Países')        
plt.ylabel('Expectativa em anos')
plt.show()

# %% [markdown]
# Para uma melhor visualização, podemos dividir o dataset. A seguir vamos tomar os 15 primeiros países do dataset.

# %%
df4 = df3.head(15)
df4.plot(x='Countries', kind='bar', stacked=False)
plt.title('Comparando as expectativa de vida em paíese africandos')
plt.xlabel('Países')        
plt.ylabel('Expectativa em anos')
plt.show()
